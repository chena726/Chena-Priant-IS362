# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame(pd.read_csv('Auto-MPG data.csv'))
#data.columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','name']
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                         name
# 0       1  "chevrolet chevelle malibu"
# 1       1  "chevrolet chevelle malibu"
# 2       1  "chevrolet chevelle malibu"
# 3       1  "chevrolet chevelle malibu"
# 4       1  "chevrolet chevelle malibu"

# %% [markdown]
# # Question 2

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# # Question 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# # Question 4

# %%
count =0
for d in data['horsepower']:
    if d == '?':
        data.drop(count,inplace=True)
        print(count)
    count+=1
print(type(data['horsepower']))
data['horsepower'] = data['horsepower'].astype(int)
print(type(data['horsepower']))
# Out:
# 32
# 126
# 330
# 336
# 354
# 374
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Question 5

# %%
count = 0
for d in data['origin']:
    if d == 1:
        data['origin'][count] = 'USA'
    elif d == 2:
        data['origin'][count] = 'Asia'
    elif d == 3:
        data['origin'][count] = 'Europe'
    count+=1
data.head(20)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0         130    3504          12.0
# 1   15.0          8         350.0         165    3693          11.5
# 2   18.0          8         318.0         150    3436          11.0
# 3   16.0          8         304.0         150    3433          12.0
# 4   17.0          8         302.0         140    3449          10.5
# 5   15.0          8         429.0         198    4341          10.0
# 6   14.0          8         454.0         220    4354           9.0
# 7   14.0          8         440.0         215    4312           8.5
# 8   14.0          8         455.0         225    4425          10.0
# 9   15.0          8         390.0         190    3850           8.5
# 10  15.0          8         383.0         170    3563          10.0
# 11  14.0          8         340.0         160    3609           8.0
# 12  15.0          8         400.0         150    3761           9.5
# ...

# %% [markdown]
# # Question 6

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
# %matplotlib inline

# %%
cylinders = data['cylinders']
a = data.groupby('cylinders').size()

y_axis = np.array(a)
x_axis = np.array(a.index[:])

ind = np.arange(len(y_axis))

plt.bar(ind,y_axis)
plt.xticks(ind,x_axis) 
plt.title('Cylinder Distribution')
# Out:
# Text(0.5, 1.0, 'Cylinder Distribution')

# %%
data.groupby('cylinders').size()
# Out:
# cylinders
# 3      4
# 4    199
# 5      3
# 6     83
# 8    103
# dtype: int64

# %% [markdown]
# # Question 7

# %%
horse_power = np.array(data['horsepower'])
weight = np.array(data['weight'])

#plt.scatter(weight, horse_power)

#plt.title('Hypothetical:Student age group and GMAT Score')

#plt.xlabel('Weight')

#plt.ylabel('Horse Power')

#plt.show()


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(horse_power,weight, s=10, c='b', marker=".")
plt.legend(loc='upper left');
plt.xlabel('Horse Power')
plt.ylabel('Weight')
plt.title('Relationship between Horse Power and Weight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Question 8: Create a bar chart that shows the distribution for model year

# %%
model_year = data['model year']
a = data.groupby('model year').size()

y_axis = np.array(a)
x_axis = np.array(a.index[:])

ind = np.arange(len(y_axis))

plt.bar(ind,y_axis)
plt.xticks(ind,x_axis) 
plt.xlabel('Year')
plt.ylabel('Number of Distribution')
plt.title('Year Distribution of Models')
# Out:
# Text(0.5, 1.0, 'Year Distribution of Models')
